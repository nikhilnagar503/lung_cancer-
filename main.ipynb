# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('dataset_med.csv')
df
# Out:
#             id   age  gender  ... treatment_type end_treatment_date survived
# 0            1  64.0    Male  ...   Chemotherapy         2017-09-10        0
# 1            2  50.0  Female  ...        Surgery         2024-06-17        1
# 2            3  65.0  Female  ...       Combined         2024-04-09        0
# 3            4  51.0  Female  ...   Chemotherapy         2017-04-23        0
# 4            5  37.0    Male  ...       Combined         2025-01-08        0
# ...        ...   ...     ...  ...            ...                ...      ...
# 889995  889996  40.0    Male  ...      Radiation         2023-02-23        0
# 889996  889997  62.0  Female  ...        Surgery         2017-06-19        0
# 889997  889998  48.0  Female  ...       Combined         2017-01-23        1
# 889998  889999  67.0  Female  ...   Chemotherapy         2017-12-12        0
# 889999  890000  55.0  Female  ...       Combined         2022-10-19        0
#
# [890000 rows x 17 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 890000 entries, 0 to 889999
# Data columns (total 15 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   id                 890000 non-null  int64
#  1   age                890000 non-null  float64
#  2   gender             890000 non-null  object
#  3   country            890000 non-null  object
#  4   cancer_stage       890000 non-null  object
#  5   family_history     890000 non-null  object
#  6   smoking_status     890000 non-null  object
#  7   bmi                890000 non-null  float64
#  8   cholesterol_level  890000 non-null  int64
#  9   hypertension       890000 non-null  int64
#  10  asthma             890000 non-null  int64
#  11  cirrhosis          890000 non-null  int64
#  12  other_cancer       890000 non-null  int64
#  13  treatment_type     890000 non-null  object
#  14  survived           890000 non-null  int64
# ...

# %%
df['cancer_stage'].dtype
# Out:
# dtype('O')

# %%
df
# Out:
#             id   age  gender  ... other_cancer treatment_type survived
# 0            1  64.0    Male  ...            0   Chemotherapy        0
# 1            2  50.0  Female  ...            0        Surgery        1
# 2            3  65.0  Female  ...            0       Combined        0
# 3            4  51.0  Female  ...            0   Chemotherapy        0
# 4            5  37.0    Male  ...            0       Combined        0
# ...        ...   ...     ...  ...          ...            ...      ...
# 889995  889996  40.0    Male  ...            0      Radiation        0
# 889996  889997  62.0  Female  ...            0        Surgery        0
# 889997  889998  48.0  Female  ...            0       Combined        1
# 889998  889999  67.0  Female  ...            0   Chemotherapy        0
# 889999  890000  55.0  Female  ...            0       Combined        0
#
# [890000 rows x 15 columns]

# %%
df.drop(columns=['diagnosis_date','end_treatment_date'],inplace=True)

# %%
for col in df:
    if df[col].dtype == 'O':
      categrary = df[col].value_counts()
      categrary.plot(kind='bar',color='skyblue')
      plt.title(f"{col} distibution")
      print(categrary)
      plt.xlabel(f'{col}')
      plt.ylabel('count ')
      plt.show()
# Out:
# gender
# Male      445134
# Female    444866
# Name: count, dtype: int64
# country
# Malta             33367
# Ireland           33243
# Portugal          33208
# France            33199
# Sweden            33161
# Croatia           33138
# Greece            33052
# Spain             33042
# Netherlands       33040
# Denmark           33024
# Slovenia          33005
# Belgium           32986
# Hungary           32981
# Romania           32963
# Poland            32949
# Italy             32948
# Germany           32940
# Estonia           32893
# Czech Republic    32885
# Lithuania         32856
# Slovakia          32853
# Austria           32832
# Finland           32798
# Luxembourg        32794
# Cyprus            32719
# Latvia            32565
# Bulgaria          32559
# Name: count, dtype: int64
# cancer_stage
# Stage III    222594
# Stage IV     222527
# Stage I      222516
# Stage II     222363
# Name: count, dtype: int64
# family_history
# No     445181
# Yes    444819
# ...

# %%
df['survived'].value_counts()
# Out:
# survived
# 0    693996
# 1    196004
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#                   id            age  ...   other_cancer       survived
# count  890000.000000  890000.000000  ...  890000.000000  890000.000000
# mean   445000.500000      55.007008  ...       0.088157       0.220229
# std    256921.014127       9.994485  ...       0.283524       0.414401
# min         1.000000       4.000000  ...       0.000000       0.000000
# 25%    222500.750000      48.000000  ...       0.000000       0.000000
# 50%    445000.500000      55.000000  ...       0.000000       0.000000
# 75%    667500.250000      62.000000  ...       0.000000       0.000000
# max    890000.000000     104.000000  ...       1.000000       1.000000
#
# [8 rows x 9 columns]

# %%
df.hist(bins=50,figsize=(20,15))  # histogram of numerical features
# Out:
# array([[<Axes: title={'center': 'id'}>, <Axes: title={'center': 'age'}>,
#         <Axes: title={'center': 'bmi'}>],
#        [<Axes: title={'center': 'cholesterol_level'}>,
#         <Axes: title={'center': 'hypertension'}>,
#         <Axes: title={'center': 'asthma'}>],
#        [<Axes: title={'center': 'cirrhosis'}>,
#         <Axes: title={'center': 'other_cancer'}>,
#         <Axes: title={'center': 'survived'}>]], dtype=object)
